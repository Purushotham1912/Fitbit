# %% [markdown]
# <a href="https://colab.research.google.com/github/Purushotham1912/Fitbit/blob/main/heartrate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mn

# %% [markdown]
# # 2.import dataset

# %%
df=pd.read_csv("/content/drive/MyDrive/prepinsta internship/week 8/heartrate_seconds_merged.csv")

# %%
df
# Out:
#                  Id                  Time  Value
# 0        2022484408  4/12/2016 7:21:00 AM     97
# 1        2022484408  4/12/2016 7:21:05 AM    102
# 2        2022484408  4/12/2016 7:21:10 AM    105
# 3        2022484408  4/12/2016 7:21:20 AM    103
# 4        2022484408  4/12/2016 7:21:25 AM    101
# ...             ...                   ...    ...
# 2483653  8877689391  5/12/2016 2:43:53 PM     57
# 2483654  8877689391  5/12/2016 2:43:58 PM     56
# 2483655  8877689391  5/12/2016 2:44:03 PM     55
# 2483656  8877689391  5/12/2016 2:44:18 PM     55
# 2483657  8877689391  5/12/2016 2:44:28 PM     56
#
# [2483658 rows x 3 columns]

# %%
df.head()
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101

# %%
df.tail()
# Out:
#                  Id                  Time  Value
# 2483653  8877689391  5/12/2016 2:43:53 PM     57
# 2483654  8877689391  5/12/2016 2:43:58 PM     56
# 2483655  8877689391  5/12/2016 2:44:03 PM     55
# 2483656  8877689391  5/12/2016 2:44:18 PM     55
# 2483657  8877689391  5/12/2016 2:44:28 PM     56

# %%
df.shape
# Out:
# (2483658, 3)

# %%
df.columns
# Out:
# Index(['Id', 'Time', 'Value'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    object
#  2   Value   int64
# dtypes: int64(2), object(1)
# memory usage: 56.8+ MB

# %%
df.describe()
# Out:
#                  Id         Value
# count  2.483658e+06  2.483658e+06
# mean   5.513765e+09  7.732842e+01
# std    1.950224e+09  1.940450e+01
# min    2.022484e+09  3.600000e+01
# 25%    4.388162e+09  6.300000e+01
# 50%    5.553957e+09  7.300000e+01
# 75%    6.962181e+09  8.800000e+01
# max    8.877689e+09  2.030000e+02

# %%
df.isnull().sum()
# Out:
# Id       0
# Time     0
# Value    0
# dtype: int64

# %%
mn.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# # 3.Data visualization[EDA]

# %% [markdown]
# # 2D plot

# %%
df['Time'].value_counts() \
.head(2483658) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Value'].value_counts() \
.head(2483658) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Time'].value_counts() \
.head(2483658) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Value'].value_counts() \
.head(2483658) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
