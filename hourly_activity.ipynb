# %% [markdown]
# <a href="https://colab.research.google.com/github/Purushotham1912/Fitbit/blob/main/hourly_activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mn

# %% [markdown]
# # 2.import datasets

# %%
df1=pd.read_csv("/content/drive/MyDrive/prepinsta internship/week 8/hourlyCalories_merged.csv")
df2=pd.read_csv("/content/drive/MyDrive/prepinsta internship/week 8/hourlyIntensities_merged.csv")
df3=pd.read_csv("/content/drive/MyDrive/prepinsta internship/week 8/hourlySteps_merged.csv")

# %%
df1
# Out:
#                Id           ActivityHour  Calories
# 0      1503960366  4/12/2016 12:00:00 AM        81
# 1      1503960366   4/12/2016 1:00:00 AM        61
# 2      1503960366   4/12/2016 2:00:00 AM        59
# 3      1503960366   4/12/2016 3:00:00 AM        47
# 4      1503960366   4/12/2016 4:00:00 AM        48
# ...           ...                    ...       ...
# 22094  8877689391  5/12/2016 10:00:00 AM       126
# 22095  8877689391  5/12/2016 11:00:00 AM       192
# 22096  8877689391  5/12/2016 12:00:00 PM       321
# 22097  8877689391   5/12/2016 1:00:00 PM       101
# 22098  8877689391   5/12/2016 2:00:00 PM       113
#
# [22099 rows x 3 columns]

# %%
df1.head()
# Out:
#            Id           ActivityHour  Calories
# 0  1503960366  4/12/2016 12:00:00 AM        81
# 1  1503960366   4/12/2016 1:00:00 AM        61
# 2  1503960366   4/12/2016 2:00:00 AM        59
# 3  1503960366   4/12/2016 3:00:00 AM        47
# 4  1503960366   4/12/2016 4:00:00 AM        48

# %%
df1.tail()
# Out:
#                Id           ActivityHour  Calories
# 22094  8877689391  5/12/2016 10:00:00 AM       126
# 22095  8877689391  5/12/2016 11:00:00 AM       192
# 22096  8877689391  5/12/2016 12:00:00 PM       321
# 22097  8877689391   5/12/2016 1:00:00 PM       101
# 22098  8877689391   5/12/2016 2:00:00 PM       113

# %%
df1.shape
# Out:
# (22099, 3)

# %%
df1.columns
# Out:
# Index(['Id', 'ActivityHour', 'Calories'], dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22099 entries, 0 to 22098
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            22099 non-null  int64
#  1   ActivityHour  22099 non-null  object
#  2   Calories      22099 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 518.1+ KB

# %%
df1.describe()
# Out:
#                  Id      Calories
# count  2.209900e+04  22099.000000
# mean   4.848235e+09     97.386760
# std    2.422500e+09     60.702622
# min    1.503960e+09     42.000000
# 25%    2.320127e+09     63.000000
# 50%    4.445115e+09     83.000000
# 75%    6.962181e+09    108.000000
# max    8.877689e+09    948.000000

# %%
df1.isnull().sum()
# Out:
# Id              0
# ActivityHour    0
# Calories        0
# dtype: int64

# %%
mn.matrix(df1)
# Out:
# <Axes: >

# %%
df2
# Out:
#                Id           ActivityHour  TotalIntensity  AverageIntensity
# 0      1503960366  4/12/2016 12:00:00 AM              20          0.333333
# 1      1503960366   4/12/2016 1:00:00 AM               8          0.133333
# 2      1503960366   4/12/2016 2:00:00 AM               7          0.116667
# 3      1503960366   4/12/2016 3:00:00 AM               0          0.000000
# 4      1503960366   4/12/2016 4:00:00 AM               0          0.000000
# ...           ...                    ...             ...               ...
# 22094  8877689391  5/12/2016 10:00:00 AM              12          0.200000
# 22095  8877689391  5/12/2016 11:00:00 AM              29          0.483333
# 22096  8877689391  5/12/2016 12:00:00 PM              93          1.550000
# 22097  8877689391   5/12/2016 1:00:00 PM               6          0.100000
# 22098  8877689391   5/12/2016 2:00:00 PM               9          0.150000
#
# [22099 rows x 4 columns]

# %%
df2.shape
# Out:
# (22099, 4)

# %%
df2.columns
# Out:
# Index(['Id', 'ActivityHour', 'TotalIntensity', 'AverageIntensity'], dtype='object')

# %%
df2.describe()
# Out:
#                  Id  TotalIntensity  AverageIntensity
# count  2.209900e+04    22099.000000      22099.000000
# mean   4.848235e+09       12.035341          0.200589
# std    2.422500e+09       21.133110          0.352219
# min    1.503960e+09        0.000000          0.000000
# 25%    2.320127e+09        0.000000          0.000000
# 50%    4.445115e+09        3.000000          0.050000
# 75%    6.962181e+09       16.000000          0.266667
# max    8.877689e+09      180.000000          3.000000

# %%
df2.isnull().sum()
# Out:
# Id                  0
# ActivityHour        0
# TotalIntensity      0
# AverageIntensity    0
# dtype: int64

# %% [markdown]
# # Merge

# %%
df1_df2_merge = pd.merge(df1,df2,how='left',on=['Id','ActivityHour'])

# %%
df1_df2_merge
# Out:
#                Id           ActivityHour  Calories  TotalIntensity  \
# 0      1503960366  4/12/2016 12:00:00 AM        81              20
# 1      1503960366   4/12/2016 1:00:00 AM        61               8
# 2      1503960366   4/12/2016 2:00:00 AM        59               7
# 3      1503960366   4/12/2016 3:00:00 AM        47               0
# 4      1503960366   4/12/2016 4:00:00 AM        48               0
# ...           ...                    ...       ...             ...
# 22094  8877689391  5/12/2016 10:00:00 AM       126              12
# 22095  8877689391  5/12/2016 11:00:00 AM       192              29
# 22096  8877689391  5/12/2016 12:00:00 PM       321              93
# 22097  8877689391   5/12/2016 1:00:00 PM       101               6
# 22098  8877689391   5/12/2016 2:00:00 PM       113               9
#
#        AverageIntensity
# 0              0.333333
# 1              0.133333
# 2              0.116667
# 3              0.000000
# 4              0.000000
# ...

# %%
df1_df2_merge.shape
# Out:
# (22099, 5)

# %%
df1_df2_merge.columns
# Out:
# Index(['Id', 'ActivityHour', 'Calories', 'TotalIntensity', 'AverageIntensity'], dtype='object')

# %%
df1_df2_merge.isnull().sum()
# Out:
# Id                  0
# ActivityHour        0
# Calories            0
# TotalIntensity      0
# AverageIntensity    0
# dtype: int64

# %%
df3
# Out:
#                Id           ActivityHour  StepTotal
# 0      1503960366  4/12/2016 12:00:00 AM        373
# 1      1503960366   4/12/2016 1:00:00 AM        160
# 2      1503960366   4/12/2016 2:00:00 AM        151
# 3      1503960366   4/12/2016 3:00:00 AM          0
# 4      1503960366   4/12/2016 4:00:00 AM          0
# ...           ...                    ...        ...
# 22094  8877689391  5/12/2016 10:00:00 AM        514
# 22095  8877689391  5/12/2016 11:00:00 AM       1407
# 22096  8877689391  5/12/2016 12:00:00 PM       3135
# 22097  8877689391   5/12/2016 1:00:00 PM        307
# 22098  8877689391   5/12/2016 2:00:00 PM        457
#
# [22099 rows x 3 columns]

# %%
df3.shape
# Out:
# (22099, 3)

# %%
df3.columns
# Out:
# Index(['Id', 'ActivityHour', 'StepTotal'], dtype='object')

# %%
df3.isnull().sum()
# Out:
# Id              0
# ActivityHour    0
# StepTotal       0
# dtype: int64

# %%
hourly_activity_merge = pd.merge(df1_df2_merge,df3,how='left',on=['Id','ActivityHour'])

# %%
hourly_activity_merge
# Out:
#                Id           ActivityHour  Calories  TotalIntensity  \
# 0      1503960366  4/12/2016 12:00:00 AM        81              20
# 1      1503960366   4/12/2016 1:00:00 AM        61               8
# 2      1503960366   4/12/2016 2:00:00 AM        59               7
# 3      1503960366   4/12/2016 3:00:00 AM        47               0
# 4      1503960366   4/12/2016 4:00:00 AM        48               0
# ...           ...                    ...       ...             ...
# 22094  8877689391  5/12/2016 10:00:00 AM       126              12
# 22095  8877689391  5/12/2016 11:00:00 AM       192              29
# 22096  8877689391  5/12/2016 12:00:00 PM       321              93
# 22097  8877689391   5/12/2016 1:00:00 PM       101               6
# 22098  8877689391   5/12/2016 2:00:00 PM       113               9
#
#        AverageIntensity  StepTotal
# 0              0.333333        373
# 1              0.133333        160
# 2              0.116667        151
# ...

# %%
hourly_activity_merge.shape
# Out:
# (22099, 6)

# %%
hourly_activity_merge.columns
# Out:
# Index(['Id', 'ActivityHour', 'Calories', 'TotalIntensity', 'AverageIntensity',
#        'StepTotal'],
#       dtype='object')

# %%
hourly_activity_merge.isnull().sum()
# Out:
# Id                  0
# ActivityHour        0
# Calories            0
# TotalIntensity      0
# AverageIntensity    0
# StepTotal           0
# dtype: int64

# %%
hourly_activity_merge
# Out:
#                Id           ActivityHour  Calories  TotalIntensity  \
# 0      1503960366  4/12/2016 12:00:00 AM        81              20
# 1      1503960366   4/12/2016 1:00:00 AM        61               8
# 2      1503960366   4/12/2016 2:00:00 AM        59               7
# 3      1503960366   4/12/2016 3:00:00 AM        47               0
# 4      1503960366   4/12/2016 4:00:00 AM        48               0
# ...           ...                    ...       ...             ...
# 22094  8877689391  5/12/2016 10:00:00 AM       126              12
# 22095  8877689391  5/12/2016 11:00:00 AM       192              29
# 22096  8877689391  5/12/2016 12:00:00 PM       321              93
# 22097  8877689391   5/12/2016 1:00:00 PM       101               6
# 22098  8877689391   5/12/2016 2:00:00 PM       113               9
#
#        AverageIntensity  StepTotal
# 0              0.333333        373
# 1              0.133333        160
# 2              0.116667        151
# ...

# %%
hourly_activity_merge.describe()
# Out:
#                  Id      Calories  TotalIntensity  AverageIntensity  \
# count  2.209900e+04  22099.000000    22099.000000      22099.000000
# mean   4.848235e+09     97.386760       12.035341          0.200589
# std    2.422500e+09     60.702622       21.133110          0.352219
# min    1.503960e+09     42.000000        0.000000          0.000000
# 25%    2.320127e+09     63.000000        0.000000          0.000000
# 50%    4.445115e+09     83.000000        3.000000          0.050000
# 75%    6.962181e+09    108.000000       16.000000          0.266667
# max    8.877689e+09    948.000000      180.000000          3.000000
#
#           StepTotal
# count  22099.000000
# mean     320.166342
# std      690.384228
# min        0.000000
# 25%        0.000000
# 50%       40.000000
# 75%      357.000000
# max    10554.000000

# %% [markdown]
# # **Data Visualization[EDA]**

# %%
hourly_activity_merge.columns
# Out:
# Index(['Id', 'ActivityHour', 'Calories', 'TotalIntensity', 'AverageIntensity',
#        'StepTotal'],
#       dtype='object')

# %%
hourly_activity_merge.shape
# Out:
# (22099, 6)

# %%
hourly_activity_merge['ActivityHour'].value_counts() \
.head(22099) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
hourly_activity_merge['Calories'].value_counts() \
.head(22099) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
hourly_activity_merge['StepTotal'].value_counts() \
.head(22099) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
hourly_activity_merge['ActivityHour'].value_counts() \
.head(22099) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
hourly_activity_merge['Calories'].value_counts() \
.head(22099) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.pairplot(hourly_activity_merge,vars=['Id', 'ActivityHour', 'Calories', 'TotalIntensity', 'AverageIntensity',
       'StepTotal'])
plt.show()

# %% [markdown]
# # 2D plots

# %%
hourly_activity_merge.plot(kind='scatter',x='ActivityHour',y='Calories')
# Out:
# <Axes: xlabel='ActivityHour', ylabel='Calories'>

# %%
hourly_activity_merge.plot(kind='scatter',x='StepTotal',y='Calories')
# Out:
# <Axes: xlabel='StepTotal', ylabel='Calories'>

# %%
hourly_activity_merge.plot(kind='scatter',x='TotalIntensity',y='Calories')
# Out:
# <Axes: xlabel='TotalIntensity', ylabel='Calories'>
