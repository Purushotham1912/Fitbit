# %% [markdown]
# <a href="https://colab.research.google.com/github/Purushotham1912/Fitbit/blob/main/sleepday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.import libraries

# %%
import numpy as np
import pandas as pd
import missingno as mn
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2.import dataset

# %%
df=pd.read_csv("/content/drive/MyDrive/prepinsta internship/week 8/sleepDay_merged.csv")

# %%
df
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# ...

# %%
df.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
df.tail()
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# 408             360
# 409             527
# 410             423
# 411             545
# 412             463

# %%
df.shape
# Out:
# (413, 5)

# %%
df.columns
# Out:
# Index(['Id', 'SleepDay', 'TotalSleepRecords', 'TotalMinutesAsleep',
#        'TotalTimeInBed'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    object
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
#  4   TotalTimeInBed      413 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 16.3+ KB

# %%
df.describe()
# Out:
#                  Id  TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# count  4.130000e+02         413.000000          413.000000      413.000000
# mean   5.000979e+09           1.118644          419.467312      458.639225
# std    2.060360e+09           0.345521          118.344679      127.101607
# min    1.503960e+09           1.000000           58.000000       61.000000
# 25%    3.977334e+09           1.000000          361.000000      403.000000
# 50%    4.702922e+09           1.000000          433.000000      463.000000
# 75%    6.962181e+09           1.000000          490.000000      526.000000
# max    8.792010e+09           3.000000          796.000000      961.000000

# %%
df.isnull().sum()
# Out:
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
mn.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# # so there is no data cleaning because the dataset is already cleaned well..

# %% [markdown]
# # 3. Data cleaning[EDA]

# %%
df['SleepDay'].value_counts() \
.head(413) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['TotalTimeInBed'].value_counts() \
.head(413) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['TotalSleepRecords'].value_counts() \
.head(413) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['TotalMinutesAsleep'].value_counts() \
.head(413) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['TotalTimeInBed'].value_counts() \
.head(413) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.pairplot(df,vars=['Id', 'SleepDay', 'TotalSleepRecords', 'TotalMinutesAsleep',
       'TotalTimeInBed'])
plt.show()

# %% [markdown]
# # 2D plot

# %%
df.plot(kind='scatter',x='TotalSleepRecords',y='TotalTimeInBed')
# Out:
# <Axes: xlabel='TotalSleepRecords', ylabel='TotalTimeInBed'>

# %%
df.plot(kind='scatter',x='SleepDay',y='TotalSleepRecords')
# Out:
# <Axes: xlabel='SleepDay', ylabel='TotalSleepRecords'>
